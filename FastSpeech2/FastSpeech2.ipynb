# %%
# !git clone https://github.com/xcmyz/FastSpeech
# Out:
# Cloning into 'FastSpeech'...
# remote: Enumerating objects: 951, done.
# remote: Counting objects: 100% (201/201), done.
# remote: Compressing objects: 100% (112/112), done.
# remote: Total 951 (delta 89), reused 191 (delta 87), pack-reused 750 (from 1)
# Receiving objects: 100% (951/951), 17.76 MiB | 16.73 MiB/s, done.
# Resolving deltas: 100% (459/459), done.
