# %%
# !git clone https://github.com/jungwhank/rcnn-text-classification-pytorch
# Out:
# Cloning into 'rcnn-text-classification-pytorch'...
# remote: Enumerating objects: 25, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 25 (delta 3), reused 21 (delta 2), pack-reused 0
# Unpacking objects: 100% (25/25), 11.26 MiB | 10.17 MiB/s, done.
